# %%
from pymongo import MongoClient
import pprint

# %%
# We're just reading data, so we can use the course cluster
client = MongoClient('mongodb://analytics-student:analytics-password@cluster0-shard-00-00-jxeqq.mongodb.net:27017,cluster0-shard-00-01-jxeqq.mongodb.net:27017,cluster0-shard-00-02-jxeqq.mongodb.net:27017/?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin')

# %%
# We'll be using two different collections this time around
movies = client.mflix.movies
surveys = client.results.surveys

# %%
# Replace XXXX with a filter document that will find the movies where "Harrison Ford" is a member of the cast
movie_filter_doc = {'cast':"Harrison Ford"}

# %%
# This is the first part of the answer to the lab
movies.find(movie_filter_doc).count()
# Out:
# 167

# %%
# Replace YYYY with a filter document to find the survey results where the "abc" product scored greater than 6
survey_filter_doc = {'results': {'$elemMatch':{'product':"abc",'score':{'$gt':6}}}}
for x in surveys.find(survey_filter_doc):
    print(x)
# Out:
# {'_id': ObjectId('5964e61ff0df64e7bc2d71e4'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d71e2'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d71cc'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d71cb'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d71ca'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 9.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d71d0'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d71d6'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d71eb'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d71f7'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d71f8'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d720b'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7227'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d724d'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d725c'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7260'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 9.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d726a'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 9.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d726d'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7289'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72bd'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72ca'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72d0'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7314'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 9.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7342'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 9.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7364'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d71da'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7224'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 9.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d724e'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7276'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d727e'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 9.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7280'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7282'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7298'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72c6'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72d3'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72ee'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7302'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7323'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 5.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d733f'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 5.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7350'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7351'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d735f'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d71f5'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7230'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7238'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 9.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d723b'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7247'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7261'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7275'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7277'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d728a'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7292'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 9.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72a0'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72b1'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72bf'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d730a'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 9.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d733d'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7368'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 9.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d736b'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d721f'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d71ed'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7252'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d71ff'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d721a'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 9.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7265'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7233'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7296'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d723a'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d729e'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72a1'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7256'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 9.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7264'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72dd'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7270'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72e7'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7301'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d729c'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 9.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d730d'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72a8'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72ba'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 9.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7328'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72ef'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7331'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72f0'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d734c'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 9.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7307'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 5.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d736a'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7317'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7318'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d731a'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7320'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7329'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d732c'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d71e0'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d71f2'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 9.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d720a'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7210'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 9.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7212'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d723c'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7242'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 9.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7246'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7258'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7293'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72a9'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72da'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72de'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72e3'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72fc'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d730e'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7310'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7327'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d71cf'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d71d7'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d71d8'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d71df'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7200'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7214'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7284'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7295'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72bb'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72c8'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72e2'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 9.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72f1'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d730b'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7315'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7319'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7334'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7335'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d735e'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 9.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d736e'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d71d9'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d71de'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 9.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7207'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7220'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d722a'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7250'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7262'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d726b'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d727f'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d729d'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72e8'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72f2'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72f7'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7305'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d731e'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7345'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7348'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7352'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7359'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d71ea'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d71ee'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d71f6'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d71fc'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 9.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7202'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7209'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7213'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d721d'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d721e'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7225'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d723e'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7248'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7274'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 9.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7279'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72c4'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 9.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72d8'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 9.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72dc'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72f9'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72fb'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d730c'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d733c'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d734f'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d71cd'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d71e1'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d71fe'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7206'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 9.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7208'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7216'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7226'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d725b'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7281'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d728c'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72bc'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72be'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72c0'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72ec'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 9.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7303'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7304'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7316'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7332'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d71f4'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d722f'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7243'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7251'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7259'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7288'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 9.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72aa'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72b5'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72c5'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72ce'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 9.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72d9'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72e4'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72f6'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 9.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7321'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7330'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 9.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7357'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7358'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7361'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d71e8'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 9.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d720c'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7211'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7245'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d726e'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d726f'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72cf'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7306'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7326'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 9.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7333'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7343'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d735b'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 5.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7369'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d71ec'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d71fd'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7201'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d721b'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d721c'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7228'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7229'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d723d'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d724c'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 9.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7263'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d727a'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7283'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d728b'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72ac'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72b0'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 9.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72b4'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72c7'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72d4'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7300'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 9.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7322'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7344'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7346'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d734e'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7362'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d736d'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d722e'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 9.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7244'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d724f'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7266'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7278'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d728d'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7297'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72a6'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 9.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72ab'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72b3'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72fa'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d731f'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7336'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d733b'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d735a'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d71ce'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d71d4'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 9.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d71d5'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d71f3'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7231'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7232'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7257'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d726c'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7294'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d729f'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72a2'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72b2'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72b6'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72c9'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72d1'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72d2'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72db'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72e5'), 'results': [{'product': 'abc', 'score': 8.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72e6'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72f8'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d732a'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d733e'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d734d'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d736c'), 'results': [{'product': 'abc', 'score': 10.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d71e3'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d71e9'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7215'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7234'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7239'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d725a'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 7.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d728e'), 'results': [{'product': 'abc', 'score': 7.0}, {'product': 'xyz', 'score': 6.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72a7'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d72ed'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d733a'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7356'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}
# {'_id': ObjectId('5964e61ff0df64e7bc2d7360'), 'results': [{'product': 'abc', 'score': 9.0}, {'product': 'xyz', 'score': 8.0}]}

# %%
# This is the second part of the answer to the lab
surveys.find(survey_filter_doc).count()
# Out:
# 295
